# %% [markdown]
# ### AutoViz Analysis Dataset for Mushrooms
#
# - **Key Visualizations**: Pair plots were used to display various groups that corresponded to edible and dangerous mushrooms
#
# - **Outliers**: For a few different kinds of mushrooms, extreme values were found in various aspects
#
# - **Suggested Readings**: It is advisable to consider preprocessing techniques and to investigate outlier cases in greater detail

# %% [markdown]
# ### AutoViz Evaluation for VGChartz DataSet
#
# - **Key Visualizations**: Features like `critic_score`, `user_score`, and `total_sales` showed distinct relationships with one another in the pair plots. Higher scores are typically associated with increased sales, demonstrating the importance of scores for a game's commercial success.
#
# - **Outliers**: The variables `total_shipped` and `total_sales` contained significant outliers. Further modeling efforts should address these outliers as they have the potential to skew the analysis.
#
# - **Feature Relationships**: Especially between `vgchartz_score` and `critic_score`, strong correlations were found, suggesting possible redundancy. Removing one of these features could make the model simpler.
#
# - **Distribution Patterns**: The `total_sales` distribution's skewness was brought to light by the visualizations, and this could have an effect on regression analysis. This realization implies that in order to improve model performance, transformations might be required to normalize this feature.

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

#Classification
reportClassification = AV.AutoViz("../Model/mushrooms.csv")

#Regression
reportRegression = AV.AutoViz("../Model/VGChartzGamesSalesDataset.csv")
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (8124, 23)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  16
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  6
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
# ...
