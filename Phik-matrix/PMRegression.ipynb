# %% [markdown]
# ### PhikMatrix Analysis for VGChartz Datasets
#
# PhikMatrix found a substantial association between `vgchartz_score` and `critic_score` in the VGChartz dataset. This redundancy suggests that in order to improve the effectiveness and interpretability of the model, we may want to consider removing one of these features in further analyses.

# %%
import phik
import pandas as pd

#Regression
dfGames = pd.read_csv("../Model/VGChartzGamesSalesDataset.csv")
dfGamesSample = dfGames.sample(500)
phik_matrixGames = dfGamesSample.phik_matrix()
phik_matrixGames
# Out:
# interval columns not set, guessing: ['vgchartz_score', 'critic_score', 'user_score', 'total_shipped', 'total_sales']
#                 name  publisher  vgchartz_score  critic_score  user_score  \
# name             1.0   1.000000        1.000000      1.000000    1.000000
# publisher        1.0   1.000000        0.000000      0.000000    0.852382
# vgchartz_score   1.0   0.000000        1.000000      0.570668    0.561636
# critic_score     1.0   0.000000        0.570668      1.000000    0.156133
# user_score       1.0   0.852382        0.561636      0.156133    1.000000
# total_shipped    1.0   0.000000        0.680172      0.409855    0.939956
# total_sales      1.0   0.000000        0.279752      0.352788    0.000000
# release_date     1.0   0.993680        0.000000      0.957563    0.000000
# genre            1.0   0.000000        0.416811      0.013445    0.000000
# img_url          1.0   0.000000        1.000000      0.908168    1.000000
#
# ...
